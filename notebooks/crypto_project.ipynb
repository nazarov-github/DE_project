# %%
import requests
import json


all_market = 'https://api.coinlore.net/api/exchanges/'
one_market = 'https://api.coinlore.net/api/exchange/?id=5'
social_stats = 'https://api.coinlore.net/api/coin/social_stats/?id=80'
coin = 'https://api.coinlore.net/api/ticker/?id=90'

response = requests.get(coin)

data = response.json()

for elem in data:
    print(elem)
# Out:
# {'id': '90', 'symbol': 'BTC', 'name': 'Bitcoin', 'nameid': 'bitcoin', 'rank': 1, 'price_usd': '117434.40', 'percent_change_24h': '1.36', 'percent_change_1h': '-0.15', 'percent_change_7d': '3.07', 'price_btc': '1.00', 'market_cap_usd': '2339592915329.50', 'volume24': 46864721486.96632, 'volume24a': 51420614878.231224, 'csupply': '19922552.00', 'tsupply': '19922552', 'msupply': '21000000'}

# %%
data
# Out:
# {'5': {'id': '5',
#   'name': 'Binance',
#   'name_id': 'binance',
#   'volume_usd': 25593564838.582767,
#   'active_pairs': 1877,
#   'url': 'https://www.binance.com',
#   'country': 'Japan'},
#  '721': {'id': '721',
#   'name': 'Pionex',
#   'name_id': 'pionex',
#   'volume_usd': 11041871296.048944,
#   'active_pairs': 300,
#   'url': 'https://www.pionex.com/',
#   'country': ''},
#  '571': {'id': '571',
#   'name': 'Indoex',
#   'name_id': 'indoex',
#   'volume_usd': 7779102440.3046665,
#   'active_pairs': 113,
#   'url': 'https://indoex.io',
#   'country': 'Estonia'},
#  '739': {'id': '739',
#   'name': 'Websea',
#   'name_id': 'websea',
#   'volume_usd': 6108589944.521522,
#   'active_pairs': 98,
#   'url': 'https://www.websea.com',
#   'country': ''},
#  '719': {'id': '719',
#   'name': 'Hotcoin Global',
#   'name_id': 'hotcoin-global',
#   'volume_usd': 5053671005.09965,
#   'active_pairs': 126,
#   'url': 'https://www.hotcoin.com/',
#   'country': 'Australia'},
# ...
